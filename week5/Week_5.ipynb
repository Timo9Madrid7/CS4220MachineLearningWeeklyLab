# %% [markdown]
# $p(w|D)=\frac{p(D|w)p(w)}{p(D)}$
#
# p(D|w): likelihood function - how probable the observed data set is for different settings of the parameter vector w
#
# $posterior\varpropto likelihood\times prior$
#
# $p(D) = \int p(D|w)p(w) dw$

# %%
import numpy as np
import prtools as pr 
import matplotlib.pyplot as plt

from jupyterthemes import jtplot
jtplot.style(theme="grade3")

# %% [markdown]
# # Exercise 5.1

# %% [markdown]
# (a)
#
# P(one of the happy few|know all of ML) = 99%
#
# P(know all of ML|one of the happy few) = $\frac{P(one \ of \ the \ happy \ few|know \ all \ of \ ML)\times P(know \ all \ of \ ML)}{P(one \ of \ the \ happy \ few)}$

# %% [markdown]
# # Exercise 5.2

# %% [markdown]
# (a)
#
# $\prod_i p_\theta(x_i)$
#
# (b)
#
# $max_\theta$ $\prod_i p_\theta(x_i)$

# %% [markdown]
# # Exercise 5.3
#
# The maximizer of the likelihood, gives us the maximum likelihood estimator for the parameter. You could say that this parameter choice maximizes the probability1 of observing our i.i.d. training data set {$x_1, . . . , x_N$} among all possible parameter choices.

# %% [markdown]
# (a)
#
# $p(\theta|x)=\frac{p(x|\theta)p(\theta)}{p(x)} \sim \frac{p(x|\theta)p(\theta)}{Z}$
#
# max $\prod p(\theta|x) \to$ max $\prod p(x|\theta)p(\theta)$
#
# (b)
#
# the total observations are fixed when we maximize the likelihood
#
# (c)
#
# $p(\theta)=constant \to max \prod p(x|\theta) \to max_{\theta} \prod p(x)$
#
# the result will be from MAP to MLE
#
# (d)
#
# $\prod p(x) = \prod \sum_\theta p(x,\theta) = \prod \sum_\theta p(x|\theta)p(\theta)$

# %% [markdown]
# # Exercise 5.4

# %% [markdown]
# # Exercise 5.5

# %% [markdown]
# (a)
#
# $p(y=-1|parameter:q)=q$ $p(y=1|parameter:q)=1-q$
#
# $\prod p(y|q)p(q) = q(q^{-1}(1-q)^{-1}) \times (1-q)(q^{-1}(1-q)^{-1}) = 1$
#
# MAP = 1, normal distribution
#
# (b)
#
# $\int \frac{1}{q(1-q)} = \int (\frac{1}{q} +\frac{1}{1-q}) = ln(q)+ln(1-q)+C$
#
# the integration of Haldane prior is larger than 1

# %%
from scipy import integrate

# %%
def f(x):
    return 1./(x*(1-x))

print(integrate.quad(f, 0.0001, 0.9999)[0])
# Out:
# 18.420480733951795

# %% [markdown]
# # Exercise 5.6

# %% [markdown]
# # Exercise 5.7

# %% [markdown]
# (a)
#
# p(x,y|w) = p(y|x,w)p(x|w) =
#
# - p(y=1|x,w)p(x|w,y=1) = p(x|y=1,w) $ \frac{1}{\sqrt{2\pi}s} e^{-\frac{(x-m_1)^2}{2s^2}} $, if y==1
#
# - p(y=2|x,w)p(x|w,y=2) = p(x|y=2,w) $ \frac{1}{\sqrt{2\pi}s} e^{-\frac{(x-m_2)^2}{2s^2}} $, if y==2

# %% [markdown]
# (b)
#
# -$\int_x \{p(x,y=1)log[p(y=1|x,w)p(x|w,y=1)] + p(x,y=2)log[p(y=2|x,w)p(x|w,y=2)]\} dx$

# %% [markdown]
# (c)(d)(e)(f)(g)(h)(i)

# %% [markdown]
# # Exercise 5.8-25

# %% [markdown]
# # Exercise 5.26

# %% [markdown]
# (a) 3

# %%
hall = pr.read_mat("hall")
pr.scatterd(hall)
print("shape of hall: ", hall.shape)
# Out:
# shape of hall:  (140, 2)

# %% [markdown]
# (b) it depends...
#
# I may use Hierarchical clustering with single linkage, and cut the dendrogram to get 3 clusters (if you want three).

# %% [markdown]
# # Exercise 5.27

# %% [markdown]
# (a)

# %%
rnd = pr.read_mat("rnd")
pr.dendro(+rnd,"complete")
# Out:
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [45.0, 45.0, 60.0, 60.0],
#   [35.0, 35.0, 52.5, 52.5],
#   [12.5, 12.5, 43.75, 43.75],
#   [75.0, 75.0, 85.0, 85.0],
#   [105.0, 105.0, 115.0, 115.0],
#   [95.0, 95.0, 110.0, 110.0],
#   [80.0, 80.0, 102.5, 102.5],
#   [135.0, 135.0, 145.0, 145.0],
#   [125.0, 125.0, 140.0, 140.0],
#   [165.0, 165.0, 175.0, 175.0],
#   [155.0, 155.0, 170.0, 170.0],
#   [132.5, 132.5, 162.5, 162.5],
#   [91.25, 91.25, 147.5, 147.5],
#   [28.125, 28.125, 119.375, 119.375],
#   [195.0, 195.0, 205.0, 205.0],
#   [225.0, 225.0, 235.0, 235.0],
#   [215.0, 215.0, 230.0, 230.0],
#   [200.0, 200.0, 222.5, 222.5],
#   [185.0, 185.0, 211.25, 211.25],
#   [245.0, 245.0, 255.0, 255.0],
#   [265.0, 265.0, 275.0, 275.0],
#   [285.0, 285.0, 295.0, 295.0],
#   [270.0, 270.0, 290.0, 290.0],
#   [250.0, 250.0, 280.0, 280.0],
#   [315.0, 315.0, 325.0, 325.0],
#   [305.0, 305.0, 320.0, 320.0],
#   [345.0, 345.0, 355.0, 355.0],
#   [335.0, 335.0, 350.0, 350.0],
#   [312.5, 312.5, 342.5, 342.5],
#   [265.0, 265.0, 327.5, 327.5],
#   [198.125, 198.125, 296.25, 296.25],
#   [73.75, 73.75, 247.1875, 247.1875],
#   [375.0, 375.0, 385.0, 385.0],
#   [365.0, 365.0, 380.0, 380.0],
#   [395.0, 395.0, 405.0, 405.0],
#   [372.5, 372.5, 400.0, 400.0],
#   [415.0, 415.0, 425.0, 425.0],
#   [455.0, 455.0, 465.0, 465.0],
#   [445.0, 445.0, 460.0, 460.0],
#   [435.0, 435.0, 452.5, 452.5],
#   [420.0, 420.0, 443.75, 443.75],
#   [386.25, 386.25, 431.875, 431.875],
#   [475.0, 475.0, 485.0, 485.0],
#   [495.0, 495.0, 505.0, 505.0],
#   [480.0, 480.0, 500.0, 500.0],
#   [535.0, 535.0, 545.0, 545.0],
#   [525.0, 525.0, 540.0, 540.0],
#   [515.0, 515.0, 532.5, 532.5],
#   [555.0, 555.0, 565.0, 565.0],
#   [595.0, 595.0, 605.0, 605.0],
#   [585.0, 585.0, 600.0, 600.0],
#   [575.0, 575.0, 592.5, 592.5],
#   [560.0, 560.0, 583.75, 583.75],
#   [523.75, 523.75, 571.875, 571.875],
#   [490.0, 490.0, 547.8125, 547.8125],
#   [409.0625, 409.0625, 518.90625, 518.90625],
#   [635.0, 635.0, 645.0, 645.0],
#   [655.0, 655.0, 665.0, 665.0],
#   [640.0, 640.0, 660.0, 660.0],
#   [625.0, 625.0, 650.0, 650.0],
#   [615.0, 615.0, 637.5, 637.5],
#   [675.0, 675.0, 685.0, 685.0],
#   [725.0, 725.0, 735.0, 735.0],
#   [715.0, 715.0, 730.0, 730.0],
#   [705.0, 705.0, 722.5, 722.5],
#   [695.0, 695.0, 713.75, 713.75],
#   [680.0, 680.0, 704.375, 704.375],
#   [626.25, 626.25, 692.1875, 692.1875],
#   [745.0, 745.0, 755.0, 755.0],
#   [775.0, 775.0, 785.0, 785.0],
#   [765.0, 765.0, 780.0, 780.0],
#   [750.0, 750.0, 772.5, 772.5],
#   [815.0, 815.0, 825.0, 825.0],
#   [805.0, 805.0, 820.0, 820.0],
#   [795.0, 795.0, 812.5, 812.5],
#   [845.0, 845.0, 855.0, 855.0],
#   [835.0, 835.0, 850.0, 850.0],
#   [803.75, 803.75, 842.5, 842.5],
#   [761.25, 761.25, 823.125, 823.125],
#   [659.21875, 659.21875, 792.1875, 792.1875],
#   [875.0, 875.0, 885.0, 885.0],
#   [895.0, 895.0, 905.0, 905.0],
#   [880.0, 880.0, 900.0, 900.0],
#   [865.0, 865.0, 890.0, 890.0],
#   [935.0, 935.0, 945.0, 945.0],
#   [925.0, 925.0, 940.0, 940.0],
#   [915.0, 915.0, 932.5, 932.5],
#   [955.0, 955.0, 965.0, 965.0],
#   [975.0, 975.0, 985.0, 985.0],
#   [960.0, 960.0, 980.0, 980.0],
#   [1015.0, 1015.0, 1025.0, 1025.0],
#   [1005.0, 1005.0, 1020.0, 1020.0],
#   [995.0, 995.0, 1012.5, 1012.5],
#   [970.0, 970.0, 1003.75, 1003.75],
#   [923.75, 923.75, 986.875, 986.875],
#   [877.5, 877.5, 955.3125, 955.3125],
#   [1035.0, 1035.0, 1045.0, 1045.0],
#   [1055.0, 1055.0, 1065.0, 1065.0],
#   [1040.0, 1040.0, 1060.0, 1060.0],
#   [1085.0, 1085.0, 1095.0, 1095.0],
#   [1075.0, 1075.0, 1090.0, 1090.0],
#   [1125.0, 1125.0, 1135.0, 1135.0],
#   [1115.0, 1115.0, 1130.0, 1130.0],
#   [1105.0, 1105.0, 1122.5, 1122.5],
#   [1145.0, 1145.0, 1155.0, 1155.0],
#   [1185.0, 1185.0, 1195.0, 1195.0],
#   [1175.0, 1175.0, 1190.0, 1190.0],
#   [1165.0, 1165.0, 1182.5, 1182.5],
#   [1150.0, 1150.0, 1173.75, 1173.75],
#   [1113.75, 1113.75, 1161.875, 1161.875],
#   [1082.5, 1082.5, 1137.8125, 1137.8125],
#   [1050.0, 1050.0, 1110.15625, 1110.15625],
#   [916.40625, 916.40625, 1080.078125, 1080.078125],
#   [725.703125, 725.703125, 998.2421875, 998.2421875],
#   [463.984375, 463.984375, 861.97265625, 861.97265625],
#   [160.46875, 160.46875, 662.978515625, 662.978515625],
#   [1215.0, 1215.0, 1225.0, 1225.0],
#   [1205.0, 1205.0, 1220.0, 1220.0],
#   [1255.0, 1255.0, 1265.0, 1265.0],
#   [1245.0, 1245.0, 1260.0, 1260.0],
#   [1235.0, 1235.0, 1252.5, 1252.5],
#   [1305.0, 1305.0, 1315.0, 1315.0],
#   [1295.0, 1295.0, 1310.0, 1310.0],
#   [1285.0, 1285.0, 1302.5, 1302.5],
#   [1275.0, 1275.0, 1293.75, 1293.75],
#   [1243.75, 1243.75, 1284.375, 1284.375],
#   [1212.5, 1212.5, 1264.0625, 1264.0625],
#   [1335.0, 1335.0, 1345.0, 1345.0],
#   [1365.0, 1365.0, 1375.0, 1375.0],
#   [1355.0, 1355.0, 1370.0, 1370.0],
#   [1340.0, 1340.0, 1362.5, 1362.5],
#   [1325.0, 1325.0, 1351.25, 1351.25],
#   [1395.0, 1395.0, 1405.0, 1405.0],
#   [1385.0, 1385.0, 1400.0, 1400.0],
#   [1415.0, 1415.0, 1425.0, 1425.0],
#   [1392.5, 1392.5, 1420.0, 1420.0],
#   [1445.0, 1445.0, 1455.0, 1455.0],
#   [1435.0, 1435.0, 1450.0, 1450.0],
#   [1465.0, 1465.0, 1475.0, 1475.0],
#   [1485.0, 1485.0, 1495.0, 1495.0],
#   [1470.0, 1470.0, 1490.0, 1490.0],
#   [1442.5, 1442.5, 1480.0, 1480.0],
#   [1406.25, 1406.25, 1461.25, 1461.25],
#   [1515.0, 1515.0, 1525.0, 1525.0],
#   [1505.0, 1505.0, 1520.0, 1520.0],
#   [1535.0, 1535.0, 1545.0, 1545.0],
#   [1512.5, 1512.5, 1540.0, 1540.0],
#   [1565.0, 1565.0, 1575.0, 1575.0],
#   [1555.0, 1555.0, 1570.0, 1570.0],
#   [1585.0, 1585.0, 1595.0, 1595.0],
#   [1605.0, 1605.0, 1615.0, 1615.0],
#   [1590.0, 1590.0, 1610.0, 1610.0],
#   [1562.5, 1562.5, 1600.0, 1600.0],
#   [1526.25, 1526.25, 1581.25, 1581.25],
#   [1433.75, 1433.75, 1553.75, 1553.75],
#   [1338.125, 1338.125, 1493.75, 1493.75],
#   [1238.28125, 1238.28125, 1415.9375, 1415.9375],
#   [1625.0, 1625.0, 1635.0, 1635.0],
#   [1645.0, 1645.0, 1655.0, 1655.0],
#   [1630.0, 1630.0, 1650.0, 1650.0],
#   [1695.0, 1695.0, 1705.0, 1705.0],
#   [1685.0, 1685.0, 1700.0, 1700.0],
#   [1675.0, 1675.0, 1692.5, 1692.5],
#   [1665.0, 1665.0, 1683.75, 1683.75],
#   [1640.0, 1640.0, 1674.375, 1674.375],
#   [1725.0, 1725.0, 1735.0, 1735.0],
#   [1715.0, 1715.0, 1730.0, 1730.0],
#   [1745.0, 1745.0, 1755.0, 1755.0],
#   [1765.0, 1765.0, 1775.0, 1775.0],
#   [1795.0, 1795.0, 1805.0, 1805.0],
#   [1785.0, 1785.0, 1800.0, 1800.0],
#   [1770.0, 1770.0, 1792.5, 1792.5],
#   [1750.0, 1750.0, 1781.25, 1781.25],
#   [1722.5, 1722.5, 1765.625, 1765.625],
#   [1657.1875, 1657.1875, 1744.0625, 1744.0625],
#   [1815.0, 1815.0, 1825.0, 1825.0],
#   [1835.0, 1835.0, 1845.0, 1845.0],
#   [1820.0, 1820.0, 1840.0, 1840.0],
#   [1855.0, 1855.0, 1865.0, 1865.0],
#   [1875.0, 1875.0, 1885.0, 1885.0],
#   [1860.0, 1860.0, 1880.0, 1880.0],
#   [1830.0, 1830.0, 1870.0, 1870.0],
#   [1915.0, 1915.0, 1925.0, 1925.0],
#   [1905.0, 1905.0, 1920.0, 1920.0],
#   [1895.0, 1895.0, 1912.5, 1912.5],
#   [1945.0, 1945.0, 1955.0, 1955.0],
#   [1935.0, 1935.0, 1950.0, 1950.0],
#   [1985.0, 1985.0, 1995.0, 1995.0],
#   [1975.0, 1975.0, 1990.0, 1990.0],
#   [1965.0, 1965.0, 1982.5, 1982.5],
#   [1942.5, 1942.5, 1973.75, 1973.75],
#   [1903.75, 1903.75, 1958.125, 1958.125],
#   [1850.0, 1850.0, 1930.9375, 1930.9375],
#   [1700.625, 1700.625, 1890.46875, 1890.46875],
#   [1327.109375, 1327.109375, 1795.546875, 1795.546875],
#   [411.7236328125, 411.7236328125, 1561.328125, 1561.328125]],
#  'dcoord': [[0.0, 0.028799433563633518, 0.028799433563633518, 0.0],
#   [0.0, 0.04636556233779234, 0.04636556233779234, 0.028799433563633518],
#   [0.0, 0.022476154038581764, 0.022476154038581764, 0.0],
#   [0.0, 0.03688439071891364, 0.03688439071891364, 0.022476154038581764],
#   [0.0, 0.11396303411365274, 0.11396303411365274, 0.03688439071891364],
#   [0.04636556233779234,
#    0.1303176543671568,
#    0.1303176543671568,
#    0.11396303411365274],
#   [0.0, 0.030434847762829276, 0.030434847762829276, 0.0],
#   [0.0, 0.04953819072668238, 0.04953819072668238, 0.0],
#   [0.0, 0.08535108749379415, 0.08535108749379415, 0.04953819072668238],
#   [0.030434847762829276,
#    0.13658401139911353,
#    0.13658401139911353,
#    0.08535108749379415],
#   [0.0, 0.019947683884871222, 0.019947683884871222, 0.0],
#   [0.0, 0.06360280393412635, 0.06360280393412635, 0.019947683884871222],
#   [0.0, 0.03791741527157718, 0.03791741527157718, 0.0],
#   [0.0, 0.0689264598903174, 0.0689264598903174, 0.03791741527157718],
#   [0.06360280393412635,
#    0.21199188947019992,
#    0.21199188947019992,
#    0.0689264598903174],
#   [0.13658401139911353,
#    0.30447540239147186,
#    0.30447540239147186,
#    0.21199188947019992],
#   [0.1303176543671568,
#    0.35957101040803446,
#    0.35957101040803446,
#    0.30447540239147186],
#   [0.0, 0.030899560702960013, 0.030899560702960013, 0.0],
#   [0.0, 0.00469564176898234, 0.00469564176898234, 0.0],
#   [0.0, 0.05269757830436447, 0.05269757830436447, 0.00469564176898234],
#   [0.030899560702960013,
#    0.07992087593111934,
#    0.07992087593111934,
#    0.05269757830436447],
#   [0.0, 0.1616914205237493, 0.1616914205237493, 0.07992087593111934],
#   [0.0, 0.047413485391596004, 0.047413485391596004, 0.0],
#   [0.0, 0.018768800822033783, 0.018768800822033783, 0.0],
#   [0.0, 0.03640378797296744, 0.03640378797296744, 0.0],
#   [0.018768800822033783,
#    0.06783351886209407,
#    0.06783351886209407,
#    0.03640378797296744],
#   [0.047413485391596004,
#    0.10676503158540311,
#    0.10676503158540311,
#    0.06783351886209407],
#   [0.0, 0.01858024737774834, 0.01858024737774834, 0.0],
#   [0.0, 0.08257027779184271, 0.08257027779184271, 0.01858024737774834],
#   [0.0, 0.04550261777881122, 0.04550261777881122, 0.0],
#   [0.0, 0.1117324929886238, 0.1117324929886238, 0.04550261777881122],
#   [0.08257027779184271,
#    0.16629444311538247,
#    0.16629444311538247,
#    0.1117324929886238],
#   [0.10676503158540311,
#    0.23120652171733871,
#    0.23120652171733871,
#    0.16629444311538247],
#   [0.1616914205237493,
#    0.4539076187354981,
#    0.4539076187354981,
#    0.23120652171733871],
#   [0.35957101040803446,
#    0.6758949399887026,
#    0.6758949399887026,
#    0.4539076187354981],
#   [0.0, 0.03768267502143961, 0.03768267502143961, 0.0],
#   [0.0, 0.0503619804283053, 0.0503619804283053, 0.03768267502143961],
#   [0.0, 0.07014316052450831, 0.07014316052450831, 0.0],
#   [0.0503619804283053,
#    0.1270863158638722,
#    0.1270863158638722,
#    0.07014316052450831],
#   [0.0, 0.06495529075305385, 0.06495529075305385, 0.0],
#   [0.0, 0.03135270693234304, 0.03135270693234304, 0.0],
#   [0.0, 0.06861011955190295, 0.06861011955190295, 0.03135270693234304],
#   [0.0, 0.09842924187077925, 0.09842924187077925, 0.06861011955190295],
#   [0.06495529075305385,
#    0.1860763603072851,
#    0.1860763603072851,
#    0.09842924187077925],
#   [0.1270863158638722,
#    0.23784577850321972,
#    0.23784577850321972,
#    0.1860763603072851],
#   [0.0, 0.0564184843465775, 0.0564184843465775, 0.0],
#   [0.0, 0.0692793449530723, 0.0692793449530723, 0.0],
#   [0.0564184843465775,
#    0.13970320737931113,
#    0.13970320737931113,
#    0.0692793449530723],
#   [0.0, 0.019218594177338184, 0.019218594177338184, 0.0],
#   [0.0, 0.05359276492774292, 0.05359276492774292, 0.019218594177338184],
#   [0.0, 0.08284677205033265, 0.08284677205033265, 0.05359276492774292],
#   [0.0, 0.029271860126782404, 0.029271860126782404, 0.0],
#   [0.0, 0.021431125617415565, 0.021431125617415565, 0.0],
#   [0.0, 0.0449093512831374, 0.0449093512831374, 0.021431125617415565],
#   [0.0, 0.06089804667511536, 0.06089804667511536, 0.0449093512831374],
#   [0.029271860126782404,
#    0.08763979601776793,
#    0.08763979601776793,
#    0.06089804667511536],
#   [0.08284677205033265,
#    0.19148080717022817,
#    0.19148080717022817,
#    0.08763979601776793],
#   [0.13970320737931113,
#    0.28742937159363957,
#    0.28742937159363957,
#    0.19148080717022817],
#   [0.23784577850321972,
#    0.4910747874227543,
#    0.4910747874227543,
#    0.28742937159363957],
#   [0.0, 0.007911813148826998, 0.007911813148826998, 0.0],
#   [0.0, 0.018756355561433957, 0.018756355561433957, 0.0],
#   [0.007911813148826998,
#    0.027223085497135088,
#    0.027223085497135088,
#    0.018756355561433957],
#   [0.0, 0.05716915503705079, 0.05716915503705079, 0.027223085497135088],
#   [0.0, 0.07655444479562937, 0.07655444479562937, 0.05716915503705079],
#   [0.0, 0.03577497225712206, 0.03577497225712206, 0.0],
#   [0.0, 0.006758520687578653, 0.006758520687578653, 0.0],
#   [0.0, 0.013527960866417924, 0.013527960866417924, 0.006758520687578653],
#   [0.0, 0.044585768275739276, 0.044585768275739276, 0.013527960866417924],
#   [0.0, 0.05660675322417262, 0.05660675322417262, 0.044585768275739276],
#   [0.03577497225712206,
#    0.09807324589266991,
#    0.09807324589266991,
#    0.05660675322417262],
#   [0.07655444479562937,
#    0.1755459108331916,
#    0.1755459108331916,
#    0.09807324589266991],
#   [0.0, 0.028372050198427985, 0.028372050198427985, 0.0],
#   [0.0, 0.03693254998874037, 0.03693254998874037, 0.0],
#   [0.0, 0.0847371368233183, 0.0847371368233183, 0.03693254998874037],
#   [0.028372050198427985,
#    0.09789848631168344,
#    0.09789848631168344,
#    0.0847371368233183],
#   [0.0, 0.015484711150009694, 0.015484711150009694, 0.0],
#   [0.0, 0.029290077336430003, 0.029290077336430003, 0.015484711150009694],
#   [0.0, 0.0798897555391706, 0.0798897555391706, 0.029290077336430003],
#   [0.0, 0.051977072237477315, 0.051977072237477315, 0.0],
#   [0.0, 0.08518534625163982, 0.08518534625163982, 0.051977072237477315],
#   [0.0798897555391706,
#    0.18192385685003445,
#    0.18192385685003445,
#    0.08518534625163982],
#   [0.09789848631168344,
#    0.2372777786798577,
#    0.2372777786798577,
#    0.18192385685003445],
#   [0.1755459108331916,
#    0.35356111879059565,
#    0.35356111879059565,
#    0.2372777786798577],
#   [0.0, 0.033553203201021585, 0.033553203201021585, 0.0],
#   [0.0, 0.04246731432549849, 0.04246731432549849, 0.0],
#   [0.033553203201021585,
#    0.08412377083756149,
#    0.08412377083756149,
#    0.04246731432549849],
#   [0.0, 0.11421046585696218, 0.11421046585696218, 0.08412377083756149],
#   [0.0, 0.03548099567458719, 0.03548099567458719, 0.0],
#   [0.0, 0.07000766945771664, 0.07000766945771664, 0.03548099567458719],
#   [0.0, 0.10731842766324406, 0.10731842766324406, 0.07000766945771664],
#   [0.0, 0.011703818329489283, 0.011703818329489283, 0.0],
#   [0.0, 0.016723570004615648, 0.016723570004615648, 0.0],
#   [0.011703818329489283,
#    0.051874135338009594,
#    0.051874135338009594,
#    0.016723570004615648],
#   [0.0, 0.012617722813812009, 0.012617722813812009, 0.0],
#   [0.0, 0.036477200995608514, 0.036477200995608514, 0.012617722813812009],
#   [0.0, 0.05394901362836341, 0.05394901362836341, 0.036477200995608514],
#   [0.051874135338009594,
#    0.13227880342001644,
#    0.13227880342001644,
#    0.05394901362836341],
#   [0.10731842766324406,
#    0.20090054101872765,
#    0.20090054101872765,
#    0.13227880342001644],
#   [0.11421046585696218,
#    0.26480560035245326,
#    0.26480560035245326,
#    0.20090054101872765],
#   [0.0, 0.04362909958825158, 0.04362909958825158, 0.0],
#   [0.0, 0.07876553264109562, 0.07876553264109562, 0.0],
#   [0.04362909958825158,
#    0.15298362749936548,
#    0.15298362749936548,
#    0.07876553264109562],
#   [0.0, 0.015814150063282597, 0.015814150063282597, 0.0],
#   [0.0, 0.055907809461326216, 0.055907809461326216, 0.015814150063282597],
#   [0.0, 0.004925182977511595, 0.004925182977511595, 0.0],
#   [0.0, 0.01674764780132621, 0.01674764780132621, 0.004925182977511595],
#   [0.0, 0.04519459155548109, 0.04519459155548109, 0.01674764780132621],
#   [0.0, 0.02602691176878185, 0.02602691176878185, 0.0],
#   [0.0, 0.006718310056798992, 0.006718310056798992, 0.0],
#   [0.0, 0.01579523696400165, 0.01579523696400165, 0.006718310056798992],
#   [0.0, 0.04776185614228507, 0.04776185614228507, 0.01579523696400165],
#   [0.02602691176878185,
#    0.08448272552665662,
#    0.08448272552665662,
#    0.04776185614228507],
#   [0.04519459155548109,
#    0.11696575583883481,
#    0.11696575583883481,
#    0.08448272552665662],
#   [0.055907809461326216,
#    0.1875074607134999,
#    0.1875074607134999,
#    0.11696575583883481],
#   [0.15298362749936548,
#    0.3082706877250343,
#    0.3082706877250343,
#    0.1875074607134999],
#   [0.26480560035245326,
#    0.4708692344517824,
#    0.4708692344517824,
#    0.3082706877250343],
#   [0.35356111879059565,
#    0.5926323853620771,
#    0.5926323853620771,
#    0.4708692344517824],
#   [0.4910747874227543,
#    0.6944375495145659,
#    0.6944375495145659,
#    0.5926323853620771],
#   [0.6758949399887026,
#    0.9912821127038492,
#    0.9912821127038492,
#    0.6944375495145659],
#   [0.0, 0.041872558273318546, 0.041872558273318546, 0.0],
#   [0.0, 0.08888461667791447, 0.08888461667791447, 0.041872558273318546],
#   [0.0, 0.021228403533247626, 0.021228403533247626, 0.0],
#   [0.0, 0.05116801213875549, 0.05116801213875549, 0.021228403533247626],
#   [0.0, 0.08503544167317066, 0.08503544167317066, 0.05116801213875549],
#   [0.0, 0.007888156510843734, 0.007888156510843734, 0.0],
#   [0.0, 0.028815305745876315, 0.028815305745876315, 0.007888156510843734],
#   [0.0, 0.05808906445871467, 0.05808906445871467, 0.028815305745876315],
#   [0.0, 0.11713435431894909, 0.11713435431894909, 0.05808906445871467],
#   [0.08503544167317066,
#    0.1705683481466624,
#    0.1705683481466624,
#    0.11713435431894909],
#   [0.08888461667791447,
#    0.2524453329778982,
#    0.2524453329778982,
#    0.1705683481466624],
#   [0.0, 0.040106774214854556, 0.040106774214854556, 0.0],
#   [0.0, 0.03271353030159129, 0.03271353030159129, 0.0],
#   [0.0, 0.0685170181517768, 0.0685170181517768, 0.03271353030159129],
#   [0.040106774214854556,
#    0.13841193903880558,
#    0.13841193903880558,
#    0.0685170181517768],
#   [0.0, 0.21171663515787562, 0.21171663515787562, 0.13841193903880558],
#   [0.0, 0.020546793167501524, 0.020546793167501524, 0.0],
#   [0.0, 0.04691628423207767, 0.04691628423207767, 0.020546793167501524],
#   [0.0, 0.06386495107516645, 0.06386495107516645, 0.0],
#   [0.04691628423207767,
#    0.09319996097596316,
#    0.09319996097596316,
#    0.06386495107516645],
#   [0.0, 0.012716803236841684, 0.012716803236841684, 0.0],
#   [0.0, 0.06389683146268219, 0.06389683146268219, 0.012716803236841684],
#   [0.0, 0.02673690475170509, 0.02673690475170509, 0.0],
#   [0.0, 0.052665845268741886, 0.052665845268741886, 0.0],
#   [0.02673690475170509,
#    0.09482443905772034,
#    0.09482443905772034,
#    0.052665845268741886],
#   [0.06389683146268219,
#    0.1304607431952626,
#    0.1304607431952626,
#    0.09482443905772034],
#   [0.09319996097596316,
#    0.24054014891908312,
#    0.24054014891908312,
#    0.1304607431952626],
#   [0.0, 0.017302082777341497, 0.017302082777341497, 0.0],
#   [0.0, 0.023050667069325986, 0.023050667069325986, 0.017302082777341497],
#   [0.0, 0.03206489577917471, 0.03206489577917471, 0.0],
#   [0.023050667069325986,
#    0.09044533136027284,
#    0.09044533136027284,
#    0.03206489577917471],
#   [0.0, 0.028537925692401284, 0.028537925692401284, 0.0],
#   [0.0, 0.04530619875359675, 0.04530619875359675, 0.028537925692401284],
#   [0.0, 0.03292521381323922, 0.03292521381323922, 0.0],
#   [0.0, 0.03623986181572287, 0.03623986181572287, 0.0],
#   [0.03292521381323922,
#    0.09692665232601813,
#    0.09692665232601813,
#    0.03623986181572287],
#   [0.04530619875359675,
#    0.16270252969385193,
#    0.16270252969385193,
#    0.09692665232601813],
#   [0.09044533136027284,
#    0.27737138873353206,
#    0.27737138873353206,
#    0.16270252969385193],
#   [0.24054014891908312,
#    0.34216788792457464,
#    0.34216788792457464,
#    0.27737138873353206],
#   [0.21171663515787562,
#    0.49113270441597806,
#    0.49113270441597806,
#    0.34216788792457464],
#   [0.2524453329778982,
#    0.5285210134264297,
#    0.5285210134264297,
#    0.49113270441597806],
#   [0.0, 0.024258731698173292, 0.024258731698173292, 0.0],
#   [0.0, 0.032674197197124076, 0.032674197197124076, 0.0],
#   [0.024258731698173292,
#    0.06495379372298508,
#    0.06495379372298508,
#    0.032674197197124076],
#   [0.0, 0.01711595790130209, 0.01711595790130209, 0.0],
#   [0.0, 0.023737256028780296, 0.023737256028780296, 0.01711595790130209],
#   [0.0, 0.059443303486773874, 0.059443303486773874, 0.023737256028780296],
#   [0.0, 0.11137354435097328, 0.11137354435097328, 0.059443303486773874],
#   [0.06495379372298508,
#    0.14409223216848,
#    0.14409223216848,
#    0.11137354435097328],
#   [0.0, 0.030571604515361606, 0.030571604515361606, 0.0],
#   [0.0, 0.044433916116553035, 0.044433916116553035, 0.030571604515361606],
#   [0.0, 0.044170478433502476, 0.044170478433502476, 0.0],
#   [0.0, 0.021372000821885305, 0.021372000821885305, 0.0],
#   [0.0, 0.009295122774282441, 0.009295122774282441, 0.0],
#   [0.0, 0.05067874996814501, 0.05067874996814501, 0.009295122774282441],
#   [0.021372000821885305,
#    0.08539734157207671,
#    0.08539734157207671,
#    0.05067874996814501],
#   [0.044170478433502476,
#    0.1433885587475418,
#    0.1433885587475418,
#    0.08539734157207671],
#   [0.044433916116553035,
#    0.171533853490454,
#    0.171533853490454,
#    0.1433885587475418],
#   [0.14409223216848,
#    0.34753526351537195,
#    0.34753526351537195,
#    0.171533853490454],
#   [0.0, 0.028734750682721973, 0.028734750682721973, 0.0],
#   [0.0, 0.07147234989834231, 0.07147234989834231, 0.0],
#   [0.028734750682721973,
#    0.12686997567345168,
#    0.12686997567345168,
#    0.07147234989834231],
#   [0.0, 0.054807147628729465, 0.054807147628729465, 0.0],
#   [0.0, 0.05835686756966913, 0.05835686756966913, 0.0],
#   [0.054807147628729465,
#    0.146707074456299,
#    0.146707074456299,
#    0.05835686756966913],
#   [0.12686997567345168,
#    0.28494433447412604,
#    0.28494433447412604,
#    0.146707074456299],
#   [0.0, 0.01450449559893629, 0.01450449559893629, 0.0],
#   [0.0, 0.06038158604384543, 0.06038158604384543, 0.01450449559893629],
#   [0.0, 0.12440997487859627, 0.12440997487859627, 0.06038158604384543],
#   [0.0, 0.03056060077409169, 0.03056060077409169, 0.0],
#   [0.0, 0.0610467167831501, 0.0610467167831501, 0.03056060077409169],
#   [0.0, 0.029650168897332345, 0.029650168897332345, 0.0],
#   [0.0, 0.056596848920863516, 0.056596848920863516, 0.029650168897332345],
#   [0.0, 0.10265159380014523, 0.10265159380014523, 0.056596848920863516],
#   [0.0610467167831501,
#    0.18491136950020254,
#    0.18491136950020254,
#    0.10265159380014523],
#   [0.12440997487859627,
#    0.3391246576394647,
#    0.3391246576394647,
#    0.18491136950020254],
#   [0.28494433447412604,
#    0.42463584459891357,
#    0.42463584459891357,
#    0.3391246576394647],
#   [0.34753526351537195,
#    0.5600133828313552,
#    0.5600133828313552,
#    0.42463584459891357],
#   [0.5285210134264297,
#    1.0396128629221795,
#    1.0396128629221795,
#    0.5600133828313552],
#   [0.9912821127038492,
#    1.3284166105079298,
#    1.3284166105079298,
#    1.0396128629221795]],
#  'ivl': ['31',
#   '15',
#   '74',
#   '70',
#   '104',
#   '39',
#   '56',
#   '68',
#   '128',
#   '137',
#   '17',
#   '185',
#   '40',
#   '85',
#   '124',
#   '131',
#   '29',
#   '126',
#   '138',
#   '49',
#   '162',
#   '181',
#   '127',
#   '172',
#   '33',
#   '191',
#   '18',
#   '63',
#   '145',
#   '180',
#   '116',
#   '142',
#   '149',
#   '19',
#   '41',
#   '107',
#   '155',
#   '47',
#   '48',
#   '50',
#   '148',
#   '45',
#   '105',
#   '152',
#   '156',
#   '86',
#   '198',
#   '118',
#   '182',
#   '67',
#   '143',
#   '32',
#   '89',
#   '13',
#   '113',
#   '64',
#   '87',
#   '102',
#   '55',
#   '88',
#   '153',
#   '129',
#   '123',
#   '84',
#   '119',
#   '44',
#   '193',
#   '26',
#   '97',
#   '146',
#   '134',
#   '95',
#   '151',
#   '179',
#   '37',
#   '187',
#   '58',
#   '14',
#   '115',
#   '27',
#   '0',
#   '158',
#   '188',
#   '43',
#   '46',
#   '173',
#   '121',
#   '1',
#   '66',
#   '9',
#   '73',
#   '101',
#   '98',
#   '144',
#   '176',
#   '75',
#   '96',
#   '36',
#   '62',
#   '167',
#   '52',
#   '122',
#   '161',
#   '103',
#   '141',
#   '81',
#   '94',
#   '109',
#   '35',
#   '178',
#   '72',
#   '4',
#   '30',
#   '60',
#   '83',
#   '91',
#   '132',
#   '199',
#   '23',
#   '65',
#   '117',
#   '69',
#   '164',
#   '54',
#   '80',
#   '22',
#   '186',
#   '8',
#   '7',
#   '59',
#   '157',
#   '168',
#   '25',
#   '99',
#   '192',
#   '57',
#   '53',
#   '160',
#   '136',
#   '2',
#   '78',
#   '120',
#   '130',
#   '16',
#   '10',
#   '196',
#   '159',
#   '174',
#   '3',
#   '189',
#   '170',
#   '51',
#   '92',
#   '38',
#   '79',
#   '76',
#   '24',
#   '147',
#   '93',
#   '183',
#   '11',
#   '34',
#   '125',
#   '163',
#   '6',
#   '165',
#   '169',
#   '42',
#   '184',
#   '90',
#   '110',
#   '197',
#   '77',
#   '194',
#   '12',
#   '154',
#   '5',
#   '171',
#   '20',
#   '21',
#   '106',
#   '82',
#   '135',
#   '61',
#   '100',
#   '111',
#   '112',
#   '28',
#   '114',
#   '177',
#   '139',
#   '133',
#   '195',
#   '71',
#   '140',
#   '166',
#   '150',
#   '175',
#   '108',
#   '190'],
#  'leaves': [31,
#   15,
#   74,
#   70,
#   104,
#   39,
#   56,
#   68,
#   128,
#   137,
#   17,
#   185,
#   40,
#   85,
#   124,
#   131,
#   29,
#   126,
#   138,
#   49,
#   162,
#   181,
#   127,
#   172,
#   33,
#   191,
#   18,
#   63,
#   145,
#   180,
#   116,
#   142,
#   149,
#   19,
#   41,
#   107,
#   155,
#   47,
#   48,
#   50,
#   148,
#   45,
#   105,
#   152,
#   156,
#   86,
#   198,
#   118,
#   182,
#   67,
#   143,
#   32,
#   89,
#   13,
#   113,
#   64,
#   87,
#   102,
#   55,
#   88,
#   153,
#   129,
#   123,
#   84,
#   119,
#   44,
#   193,
#   26,
#   97,
#   146,
#   134,
#   95,
#   151,
#   179,
#   37,
#   187,
#   58,
#   14,
#   115,
#   27,
#   0,
#   158,
#   188,
#   43,
#   46,
#   173,
#   121,
#   1,
#   66,
#   9,
#   73,
#   101,
#   98,
#   144,
#   176,
#   75,
#   96,
#   36,
#   62,
#   167,
#   52,
#   122,
#   161,
#   103,
#   141,
#   81,
#   94,
#   109,
#   35,
#   178,
#   72,
#   4,
#   30,
#   60,
#   83,
#   91,
#   132,
#   199,
#   23,
#   65,
#   117,
#   69,
#   164,
#   54,
#   80,
#   22,
#   186,
#   8,
#   7,
#   59,
#   157,
#   168,
#   25,
#   99,
#   192,
#   57,
#   53,
#   160,
#   136,
#   2,
#   78,
#   120,
#   130,
#   16,
#   10,
#   196,
#   159,
#   174,
#   3,
#   189,
#   170,
#   51,
#   92,
#   38,
#   79,
#   76,
#   24,
#   147,
#   93,
#   183,
#   11,
#   34,
#   125,
#   163,
#   6,
#   165,
#   169,
#   42,
#   184,
#   90,
#   110,
#   197,
#   77,
#   194,
#   12,
#   154,
#   5,
#   171,
#   20,
#   21,
#   106,
#   82,
#   135,
#   61,
#   100,
#   111,
#   112,
#   28,
#   114,
#   177,
#   139,
#   133,
#   195,
#   71,
#   140,
#   166,
#   150,
#   175,
#   108,
#   190],
#  'color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C0',
#   'C0']}

# %% [markdown]
# (b)

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram

# %%
# D = rnd*pr.proxm(rnd,('eucl',2))
# plt.figure(figsize=(16,8))
# plt.subplot(1,3,1)
# lab_complete = pr.hclust(D, 'complete', 3)
# pr.scatterd(pr.prdataset(+rnd,lab_complete))
# plt.subplot(1,3,2)
# lab_single = pr.hclust(D, 'single', 3)
# pr.scatterd(pr.prdataset(+rnd,lab_single))
# plt.subplot(1,3,3)
# # (DXD: Sorry, not implemented yet!)
# # lab_average = pr.hclust(D, 'average', 3)
# # pr.scatterd(pr.prdataset(+rnd,lab_average))

# %%
# I will use sklearn here instead of prtools, as they don't implement average link!?!?

cluster_single = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='single').fit(+rnd)
cluster_complete = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete').fit(+rnd)
cluster_average = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='average').fit(+rnd)

plt.figure(figsize=(20,8))
plt.subplot(1,3,1)
pr.scatterd(pr.prdataset(+rnd, cluster_single.labels_))
plt.title("single linkage")
plt.subplot(1,3,2)
pr.scatterd(pr.prdataset(+rnd, cluster_complete.labels_))
plt.title("complete linkage")
plt.subplot(1,3,3)
pr.scatterd(pr.prdataset(+rnd, cluster_average.labels_))
plt.title("average linkage")
plt.show()

# %%
temp1 = pr.dendro(+rnd,"single")
temp2 = pr.dendro(+rnd,"average")

#↓ sklearn also provides the method to plot dendrogram ↓ 
# scikit-learn.org/stable/auto_examples/cluster/plot_agglomerative_dendrogram.html#sphx-glr-auto-examples-cluster-plot-agglomerative-dendrogram-py

# %% [markdown]
# In terms of average linkage, it performs almost the same as complete linkage, except for the length of the stems; however, single linkage varies from both of them. Since there are lots of "leaps" using single linkage, average and complete linkages are more suitable for this data set.

# %% [markdown]
# # Exercise 5.28

# %%
hall_dendro = pr.dendro(+hall,"complete")
D = hall*pr.proxm(hall,('eucl',2))
hall_complete = pr.hclust(D, 'complete', 3)
pr.scatterd(pr.prdataset(+hall,hall_complete))

# %% [markdown]
# (a)
#
# The stems tell us the distance between two clusters which have joined into one cluster. Since it ueses complete linkage, the distance is measured by furthest two points in the clusters.
#
# >Ans: These lengths correspond to the distances (single, average or complete linkage) between the two clusters being joined by the bridge consisting of two stems and a vertical bar.

# %% [markdown]
# (b)
#
# Cutting the gendrogram with the largest average leap/jump is often a proper solution, but it always depends on the practical data sets and reality.
#
# >Ans: The closer together the samples in a cluster and the further apart the clusters, the better the
# clustering.

# %% [markdown]
# (c)
#
# Long stems correspond to large distances between clusters and therefore a potential point to
# cut the dendrogram.

# %% [markdown]
# (d)

# %%
hall_dendro = pr.dendro(+hall,"single")
D = hall*pr.proxm(hall,('eucl',2))
hall_single = pr.hclust(D, 'single', 3)
pr.scatterd(pr.prdataset(+hall,hall_single))

# %% [markdown]
# It is more obvious to distinguish different small and large clusters according to the single linkage, where all the different clusters almost "make a great jump" together. Turning to complete linkage, this phenomenon is less pronounced.
#
# >Ans: Yes, in the single linkage dendrogram, there are basically two lengths of vertical stems: those
# indicating the joining of the smallest clusters, and those indicating the joining of the larger three
# clusters. This is less pronounced with complete linkage.

# %% [markdown]
# (e)

# %%
hall_dendro = pr.dendro(+hall,"average")

# %% [markdown]
# It is more similar to complete linkage and varies a lot to single linkage
#
# >Ans: The average linkage dendrogram is roughly similar to the complete linkage dendrogram

# %% [markdown]
# # Exercise 5.29

# %% [markdown]
# (a)

# %%
triclust = pr.read_mat("triclust")

# %%
shape = ['full', 'diag', 'sphr']
plt.figure(figsize=(22,10))
for i in range(len(shape)):
    plt.subplot(1,3,i+1)
    w = pr.mog(triclust, (3,shape[i],0.01))
    pr.scatterd(triclust)
    pr.plotm(w)
    pred = w(triclust)
    logL = np.sum(np.log(np.sum(+pred,axis=1)))
    plt.title(shape[i]+", log-probabilities:" + str(np.round(logL,4)))
plt.show()

# %% [markdown]
# (b)

# %%
cigars = pr.read_mat("cigars")

# %%
plt.figure(figsize=(22,10))
for k in range(1, 6):
    plt.subplot(1,5,k)
    w = pr.mog(cigars, (k,'full',0.001))
    pr.scatterd(cigars)
    pr.plotm(w)
    pred = w(cigars)
    logL = np.sum(np.log(np.sum(+pred,axis=1)))
    plt.title("k="+ str(k) +", log-probabilities:" + str(np.round(logL,4)))
plt.show()

# %% [markdown]
# (c)

# %%
messy = pr.read_mat('messy')

# %%
pr.scatterd(messy)

# %%
w = pr.mog(messy, (2,'diag',0.01))
pr.scatterd(messy)
pr.plotm(w)
pred = w(messy)
logL = np.sum(np.log(np.sum(+pred,axis=1)))
print("log-probabilities:", logL)
# Out:
# log-probabilities: 1533.6645803225229

# %%
w = pr.mog(messy, (2,'sphr',0.01))
pr.scatterd(messy)
pr.plotm(w)
pred = w(messy)
logL = np.sum(np.log(np.sum(+pred,axis=1)))
print("log-probabilities:", logL)
# Out:
# log-probabilities: 1522.7161569139125

# %% [markdown]
# # Exercise 5.30
#
# A simple heuristic to
# determine the number of clusters in hierarchical clustering is to cut the dendrogram at the
# point where we observe a large jump in the fusion graph.

# %% [markdown]
# (a)
#
# >Ans: A large jump in the fusion graph implies that two clusters were merged that were, relative to
# the other cluster distances, quite far apart

# %% [markdown]
# # Exercise 5.31

# %% [markdown]
# (a) k = 3

# %%
triclust = pr.read_mat("triclust")

# %%
triclust_fusion = pr.fusion_graph(+triclust, 'single')

# %% [markdown]
# (b)

# %%
triclust_fusion = pr.fusion_graph(+triclust, 'complete')

# %% [markdown]
# >Ans: The fusion graph is ambiguous about the exact number of clusters: either two or three clusters
# are associated with large fusion jumps of roughly the same magnitude. This is due to the complete
# linkage distance: distance between furthest samples of clusters at (0, 0) and (1, 1) (which are
# merged to result from a total of two clusters) is roughly half the distance between the distance
# between the furthest samples in the cluster at (0, 0) and (2, 2), which are merged to result in
# a single cluster. In single linkage this does not occur, since the minimal distances between the
# clusters at (0, 0) and (1, 1) is the same as the minimal distance between the clusters at (1, 1) and
# (2, 2).

# %% [markdown]
# # Exercise 3.32

# %%
hall = pr.read_mat('hall')

# %%
pr.fusion_graph(+hall, 'single')

# %% [markdown]
#  There are two pronounced jumps, at 3 and 14 clusters.

# %% [markdown]
# # Exercise 5.33

# %% [markdown]
# (a)
# k = 3

# %%
messy = pr.read_mat('messy')

# %%
pr.fusion_graph(+messy, 'single')

# %% [markdown]
# (b) In the dendrogram, the first two clusters only contain some outliers while all the other points are in the third cluster.
#
# >Ans: No, three outliers constitute the members of two of the three clusters with all the other samples in the third cluster

# %% [markdown]
# (c)

# %%
pr.fusion_graph(+messy, 'complete')

# %% [markdown]
# k = 2, much better now!
#
# >Ans: While the size of the fusion jump is not very convincing (not much larger than the other jumps) the resulting clustering is better. This stems from the fact that complete linkage is less prone to outliers than single linkage.

# %% [markdown]
# # Exercise 3.34
#
# Formally, this measure is known as the Davies-Bouldin index (DBI). It assumes that
# clusters are spherical, and that a desirable clustering consists of compact clusters that are
# well-separated. (组内距离最小，组间距离最大)
#
# - there are <b>g</b> clusters;
# - the mean of a cluster is its centroid, denoted as $\mu_j$, and the 2-norm distance between centroids $|| \mu_j - \mu_k ||$ represents the distance between clusters.
# - the standard variance of a cluster $\sigma_j$ represents its distances within the cluster.
# $$\sigma_j = \sqrt{\frac{1}{n_j} \sum_{x_i\in C_j}||x_i-\mu_j||^2}$$
# - DBI score:
# $$R_{jk} = \frac{\sigma_j+\sigma_k}{|| \mu_j-\mu_k ||}, \ j,k=1,2,3...,g; \ k\neq j$$
# we <b>expect</b> this score as small as possible, as "clustering consists of compact clusters that are
# well-separated".
# - If there are many pairs (g>2), then $R_j=max_{k=1,2,...g; k\neq j} R_{jk}$ <- We take the worest case as consideration
# - Davies-Bouldin index:
# $$I_{DB} = \frac{1}{g} \sum_{j=1}^g R_j$$

# %% [markdown]
# (a)

# %%
pr.scatterd(hall)

# %%
# g = 3

hall_cluster_single = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='single').fit(+hall)
e = pr.dbi(+hall, hall_cluster_single.labels_)
print("DBI of hall_cluster_single: ", e)
# Out:
# DBI of hall_cluster_single:  0.389130779261571

# %%
# g = 14

hall_cluster_single = AgglomerativeClustering(n_clusters=14, affinity='euclidean', linkage='single').fit(+hall)
e = pr.dbi(+hall, hall_cluster_single.labels_)
print("DBI of hall_cluster_single: ", e)
# Out:
# DBI of hall_cluster_single:  0.26184506782678124

# %%
# g = 5

hall_cluster_single = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='single').fit(+hall)
e = pr.dbi(+hall, hall_cluster_single.labels_)
print("DBI of hall_cluster_single: ", e)
# Out:
# DBI of hall_cluster_single:  0.7613479379749362

# %% [markdown]
# (b) it should at least <b>3</b> clusters

# %%
pr.scatterd(triclust)

# %% [markdown]
# (c)

# %%
dbi = np.zeros([9])
for k in range(2,11):
    cluster = AgglomerativeClustering(k, linkage="complete").fit(+triclust)
    dbi[k-2] = pr.dbi(+triclust, cluster.labels_)

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(2,11), dbi, "-D")
plt.title("triclust: DBI Curve")
plt.xlabel("#Clusters")
plt.ylabel("DBI")
plt.show()

# %% [markdown]
# 3 is the minimum; therefore, the number of clusters should be 3

# %% [markdown]
# (d)

# %%
pr.scatterd(hall)

# %%
dbi = np.zeros([19])
for k in range(2,21):
    cluster = AgglomerativeClustering(k, linkage="complete").fit(+hall)
    dbi[k-2] = pr.dbi(+hall, cluster.labels_)

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(2,21), dbi, "-D")
plt.title("hall: DBI Curve")
plt.xlabel("#Clusters")
plt.ylabel("DBI")
plt.show()

# %% [markdown]
# There is a pronounced minimum at 14 clusters and a slightly larger minimum at 3 clusters.
#
# The first minimum (3 clusters) corresponds to the situation where the smaller clusters are grouped in three large clusters (four in top-left, four in top-right and six at the bottom) while the minimum at 14 corresponds to the fine cluster structure in the data.
#
# The peak at 14 is more pronounced since the ratio of the maximal within-scatter to the minimal distance between any pair of these clusters is smaller than for the three cluster configuration.
